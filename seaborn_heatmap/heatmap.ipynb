# %%
import seaborn as sns

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ## 🔴Creating a Pivot Table

# %%
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %% [markdown]
# ## 🔴Creating a Heatmap

# %%
sns.heatmap(data=flights_pivot)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴This key parameter stands for "annotate". It instructs the function to write the data value (the actual number of passengers) inside each cell of the heatmap.

# %%
sns.heatmap(data=flights_pivot, annot=True)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴Formats the annotated numbers as integers (decimals), removing any fractional part. This is crucial for count data like passengers, ensuring clean, whole-number labels.

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴This is a keyword arguments parameter for the annotations. It passes a dictionary of styling options to the text elements. Here, it sets the text color to black.

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", annot_kws={"color":"black"})
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴cmap="coolwarm": This parameter changes the color map (the palette used to represent data values). The "coolwarm" palette typically uses blue for low values, white for mid-range, and red for high values.

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴linewidths=5: This parameter sets the width of the lines that will be drawn between each cell in the heatmap, creating a distinct grids.

# %% [markdown]
# ## 🔴linecolor="pink": This parameter defines the color of those grid lines.

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm",linewidths=5,linecolor="pink")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴vmin=200: This parameter sets the minimum value of the color scale. Any data value at or below 200 will be mapped to the lowest color in the palette (e.g., dark blue in "coolwarm").).

# %% [markdown]
# ## 🔴vmax=500: This parameter sets the maximum value of the color scale. Any data value at or above 500 will be mapped to the highest color in the palette (e.g., dark red in "coolwarm").

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm", vmin=200, vmax=500)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴Removing the Color Bar

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm", cbar=False)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴Customizing the Color Bar

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm", cbar_kws={"orientation":"horizontal", "shrink":8})
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴center=600: This parameter defines the data value that will be mapped to the central color (typically white) in a diverging colormap like "coolwarm". The color scale diverges from this central point.

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm", center=600)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴Adjusting Heatmap Transparency

# %%
sns.heatmap(data=flights_pivot, annot=True, fmt="d", cmap="coolwarm", alpha=0.2)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ## 🔴This function from the Seaborn library plots a hierarchically-clustered heatmap

# %%
sns.clustermap(data=flights_pivot)

# %%
sns.clustermap(data=flights_pivot, row_cluster=False)

# %% [markdown]
# ## 🔴Linkage method for clustering.	'average', 'ward', 'single'

# %%
sns.clustermap(data=flights_pivot, method="ward")

# %% [markdown]
# ## 🔴Distance metric for clustering.	'euclidean', 'correlation'

# %%
sns.clustermap(data=flights_pivot, metric="cosine")

# %% [markdown]
# ## 🔴Normalizes data by row (0) or column (1).

# %%
sns.clustermap(data=flights_pivot, metric="cosine", z_score=1)

# %% [markdown]
# ## 🔴Standardizes data by row (0) or column (1).

# %%
sns.clustermap(data=flights_pivot, metric="cosine", standard_scale=1)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
#
# https://seaborn.pydata.org/generated/seaborn.clustermap.html
