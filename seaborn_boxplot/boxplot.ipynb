# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## 🔴you can use seaborn to draw a box plot.

# %%
sns.boxplot(x="day", y="tip", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You can specify the hue.

# %%
sns.boxplot(x="day", y="tip", data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You can specify the palette.

# %%
sns.boxplot(x="day", y="tip", data=tips, palette="coolwarm", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You can change box width.

# %%
sns.boxplot(x="day", y="tip", data=tips, width=1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You can specify the line width.

# %%
sns.boxplot(x="day", y="tip", data=tips, linewidth=5)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You use showfliers=False to create a cleaner plot that focuses on the main body of the data (the quartiles and median) without the visual distraction of extreme values.

# %%
sns.boxplot(x="day", y="tip", data=tips, showfliers= False)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You can change the orientaion.

# %%
sns.boxplot(x="tip", y="day", data=tips, orient="h")
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ## 🔴You can specify the hue.

# %%
sns.boxplot(x="day", y="tip", data=tips,notch=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y="tip", data=tips, medianprops={"color":"white"})
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y="tip", data=tips, showmeans=True,meanline=True )
# Out:
# <Axes: xlabel='day', ylabel='tip'>
