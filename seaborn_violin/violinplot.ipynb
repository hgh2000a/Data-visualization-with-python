# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## 🔴you can use seaborn to draw a violin plot.

# %%
sns.violinplot(x="day", y="tip", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴You can specify the hue.

# %%
sns.violinplot(x="day", y="tip", data=tips, hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴In a Seaborn violin plot, the split=True option draws the distributions for different hue categories on opposite sides of the same violin instead of overlapping them, making it easier to compare the two groups within each category.

# %%
sns.violinplot(x="day", y="tip", data=tips, hue="sex", split=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴density_norm="area" (default) → Each violin is scaled so that the total area under its KDE (distribution) is the same. This makes shapes comparable in terms of distribution, not counts.

# %%
sns.violinplot(x="day", y="tip", data=tips, density_norm="area")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴density_norm="count" → The width is proportional to the number of observations in each category, so categories with more data look wider.

# %%
sns.violinplot(x="day", y="tip", data=tips, density_norm="count")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day", y="tip", data=tips, inner=None)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day", y="tip", data=tips, inner="quartile")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴In a Seaborn violin plot, the parameter bw_method controls the bandwidth of the kernel density estimator (KDE) that shapes the violin:

# %%
sns.violinplot(x="day", y="tip", data=tips, bw_method=0.2)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴In a Seaborn violin plot, the parameter cut controls how far the violin extends beyond the range of the actual data:

# %%
sns.violinplot(x="day", y="tip", data=tips, cut=0)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## 🔴In a Seaborn violin plot, the inner parameter controls what is drawn inside each violin to represent the data distribution:
#
# ## inner="box" (default) → shows a small boxplot inside the violin
#
# ## inner="quartile" → shows horizontal lines at the quartiles
#
# ## inner="point" → shows individual data points
#
# ## inner="stick" → shows each data point as a short vertical line (like a rug plot)
#
# ## inner=None → nothing is drawn inside

# %%
sns.violinplot(x="day", y="tip", data=tips, inner="stick")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x="day", y="tip", data=tips, inner="point")
# Out:
# <Axes: xlabel='day', ylabel='tip'>
