# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("diamonds")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ## 🔴You can directly use the pandas library to plot a histogram.

# %%
df.hist(column="carat")
# Out:
# array([[<Axes: title={'center': 'carat'}>]], dtype=object)

# %% [markdown]
# ## 🔴You can change the bins. Its default is 10.

# %%
df.hist(column="carat", bins=5)
# Out:
# array([[<Axes: title={'center': 'carat'}>]], dtype=object)

# %% [markdown]
# ## 🔴You can use the seaborn library to plot a histogram.

# %%
sns.histplot(data=df, x="carat")
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %% [markdown]
# ## 🔴The bins are selected automatically, but they can also be changed manually.

# %%
sns.histplot(data=df, x="carat", bins=10)
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %% [markdown]
# ## 🔴You can set the kde parameter to True.

# %%
sns.histplot(data=df, x="carat", kde=True)
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %% [markdown]
# ## 🔴You can assign custom labels and choose a name for the plot.

# %%
ax = sns.histplot(data=df, x="carat", kde=True)
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count")
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count')]

# %% [markdown]
# ## 🔴You use the color parameter to change the color.

# %%
ax = sns.histplot(data=df, x="carat", kde=True, color="red")
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count")
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count')]

# %% [markdown]
# ## 🔴You can specify the hue.

# %%
ax = sns.histplot(data=df, x="carat", kde=True, color="red", hue="cut")
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count")
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count')]

# %% [markdown]
# ## 🔴You can specify different elements that change the display, for example, poly has been drawn.

# %%
ax = sns.histplot(data=df, x="carat", kde=True, color="red", element="poly")
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count")
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count')]

# %% [markdown]
# ## 🔴The x and y values are limited using xlim and ylim.

# %%
ax = sns.histplot(data=df, x="carat", element="poly")
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count",xlim=(0,3),ylim=(0,4000))
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count'),
#  (0.0, 3.0),
#  (0.0, 4000.0)]

# %% [markdown]
# ## 🔴You can specify the x and y axis divisions yourself.

# %%
ax = sns.histplot(data=df, x="carat")
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count",xticks=(1,2),yticks=(2000,5000))
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count'),
# ...

# %% [markdown]
# ## 🔴You can label each section of the x and y axes.

# %%
ax = sns.histplot(data=df, x="carat")
ax.set(title="histogram of carat", xlabel="Carat", ylabel="Count",xticks=(1,2),yticks=(2000,5000),yticklabels=("bad","good"))
# Out:
# [Text(0.5, 1.0, 'histogram of carat'),
#  Text(0.5, 0, 'Carat'),
#  Text(0, 0.5, 'Count'),
# ...
#  [Text(0, 2000, 'bad'), Text(0, 5000, 'good')]]
