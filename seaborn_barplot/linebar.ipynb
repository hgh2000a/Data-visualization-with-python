# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("diamonds")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ## 🔴You can draw a bar plot using pandas.

# %%
table = pd.crosstab(df["cut"], columns="count")
table
# Out:
# col_0      count
# cut
# Ideal      21551
# Premium    13791
# Very Good  12082
# Good        4906
# Fair        1610

# %%
table.plot(kind="bar")
# Out:
# <Axes: xlabel='cut'>

# %% [markdown]
# ## 🔴You can also use the seaborn library and catplot to draw a bar chart.

# %%
sns.catplot(data=df, x="cut", kind="count")

# %% [markdown]
# ## 🔴Changing the aspect changes the width of the rectangles.

# %%
sns.catplot(data=df, x="cut", kind="count", aspect=3)

# %% [markdown]
# ## 🔴You can change the color and palette.

# %%
sns.catplot(data=df, x="cut", kind="count", color="m")

# %%
sns.catplot(data=df, x="cut", kind="count", palette="dark", hue="cut")

# %% [markdown]
# ## 🔴The order of the columns is also adjustable.

# %%
sns.catplot(data=df, x="cut", kind="count", palette="dark", hue="cut",
           order=['Ideal', 'Fair','Premium', 'Good', 'Very Good'])

# %% [markdown]
# ## 🔴Sets the seaborn style to a white grid background.

# %%
sns.set(style="whitegrid")

# %%
sns.barplot(data=df, x="cut", y="price")
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %% [markdown]
# ## 🔴You can change the estimator type from the default mean to, for example, median.

# %%
sns.barplot(data=df, x="cut", y="price",estimator=np.median)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %% [markdown]
# ## 🔴You can specify the hue.

# %%
sns.barplot(data=df, x="cut", y="price",estimator=np.mean, hue="color")
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %% [markdown]
# ## 🔴You can swap the x and y.

# %%
sns.barplot(data=df, y="cut", x="price",estimator=np.mean, orient="h")
# Out:
# <Axes: xlabel='price', ylabel='cut'>

# %% [markdown]
# ## 🔴You can configure the errorbar according to your needs.

# %%
sns.barplot(data=df, x="cut", y="price",estimator=np.mean, errorbar=None)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.barplot(data=df, x="cut", y="price",estimator=np.mean, errorbar=("ci",99))
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.barplot(data=df, x="cut", y="price",estimator=np.mean, errorbar=("ci",99), capsize=0.3)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %% [markdown]
# ## 🔴The box for hues has customization capabilities, examples of which are provided below.

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.legend(title="COLOR")

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.legend(title="COLOR", loc="upper left")

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.legend(title="COLOR", loc="upper left", fontsize=20)

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.legend(title="COLOR", loc="upper left", fontsize=20, title_fontsize=50)

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.legend(title="COLOR", loc="upper left",ncol=5)

# %% [markdown]
# ## 🔴You can change the y-label and x-label.

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.set_ylabel("PRICE", fontsize=20)
ax.set_xlabel("CUT", fontsize=20)
# Out:
# Text(0.5, 0, 'CUT')

# %% [markdown]
# ## 🔴Sets the x-axis tick labels with a font size of 10 and rotates them 45 degrees.

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10, rotation=45)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5428\2449387381.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), fontsize=10, rotation=45)
# [Text(0, 0, 'Ideal'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Very Good'),
#  Text(3, 0, 'Good'),
#  Text(4, 0, 'Fair')]

# %% [markdown]
# ## 🔴Enables grid lines for both axes with a dashed line style and 60% opacity.

# %%
ax = sns.barplot(data=df, x="cut", y="price", hue="color")
ax.grid(True, axis="both", linestyle="--", alpha=0.6)

# %% [markdown]
#     https://seaborn.pydata.org/generated/seaborn.catplot.html
#
#     https://seaborn.pydata.org/generated/seaborn.barplot.html
#
#     https://matplotlib.org/stable/gallery/color/named_colors.html
#
#     https://seaborn.pydata.org/tutorial/aesthetics.html
#
#     https://seaborn.pydata.org/tutorial/color_palettes.html
#
#     https://seaborn.pydata.org/generated/seaborn.barplot.html
