# %%
import seaborn as sns

# %%
mpg = sns.load_dataset("mpg")
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## 🔴This data is not suitable for a scatter plot, so we move on to a line plot.

# %%
sns.scatterplot(data=mpg, x="model_year", y="horsepower")
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %%
sns.lineplot(data=mpg, x="model_year", y="horsepower")
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %% [markdown]
# ## 🔴You can specify the ci (confidence interval) as desired.

# %%
sns.lineplot(data=mpg, x="model_year", y="horsepower", errorbar=("ci",20))
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %% [markdown]
# ## 🔴You can change the line width.

# %%
sns.lineplot(data=mpg, x="model_year", y="horsepower", errorbar=("ci",20),linewidth=5)
# Out:
# <Axes: xlabel='model_year', ylabel='horsepower'>

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ## 🔴You can specify the hue.

# %%
sns.lineplot(data=flights, x="year", y="passengers", errorbar=("ci",0),hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## 🔴An example for plotting a chart for three specific months.

# %%
months = ["Jan", "Jun", "Dec"]
for month in months:
    month_flight = flights[flights["month"] == month]
    sns.lineplot(data=month_flight, x="year", y="passengers", errorbar=("ci",0),label=month)
